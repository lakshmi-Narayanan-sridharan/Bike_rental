# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmi-Narayanan-sridharan/Bike_rental/blob/main/Pharma%20sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e73e79d2-1d83-42fa-8d1d-85587eb75879" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e73e79d2-1d83-42fa-8d1d-85587eb75879">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving salesdaily.csv to salesdaily.csv

# %%
df = pd.read_csv('salesdaily.csv')
df
# Out:
#           datum  M01AB   M01AE  N02BA  ...  Year  Month  Hour  Weekday Name
# 0      1/2/2014   0.00   3.670   3.40  ...  2014      1   248      Thursday
# 1      1/3/2014   8.00   4.000   4.40  ...  2014      1   276        Friday
# 2      1/4/2014   2.00   1.000   6.50  ...  2014      1   276      Saturday
# 3      1/5/2014   4.00   3.000   7.00  ...  2014      1   276        Sunday
# 4      1/6/2014   5.00   1.000   4.50  ...  2014      1   276        Monday
# ...         ...    ...     ...    ...  ...   ...    ...   ...           ...
# 2101  10/4/2019   7.34   5.683   2.25  ...  2019     10   276        Friday
# 2102  10/5/2019   3.84   5.010   6.00  ...  2019     10   276      Saturday
# 2103  10/6/2019   4.00  11.690   2.00  ...  2019     10   276        Sunday
# 2104  10/7/2019   7.34   4.507   3.00  ...  2019     10   276        Monday
# 2105  10/8/2019   0.33   1.730   0.50  ...  2019     10   190       Tuesday
#
# [2106 rows x 13 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#importing library files

# %%
df.head()
# Out:
#       datum  M01AB  M01AE  N02BA  N02BE  ...  R06  Year  Month  Hour  Weekday Name
# 0  1/2/2014    0.0   3.67    3.4  32.40  ...  2.0  2014      1   248      Thursday
# 1  1/3/2014    8.0   4.00    4.4  50.60  ...  4.0  2014      1   276        Friday
# 2  1/4/2014    2.0   1.00    6.5  61.85  ...  1.0  2014      1   276      Saturday
# 3  1/5/2014    4.0   3.00    7.0  41.10  ...  0.0  2014      1   276        Sunday
# 4  1/6/2014    5.0   1.00    4.5  21.70  ...  2.0  2014      1   276        Monday
#
# [5 rows x 13 columns]

# %%
sns.pairplot(data = df)

# %%
sns.countplot(data = df, x = 'Year')
plt.show()
# This shows that the year 2019 has lesser No of working days which will result in fall of sales

# %%
df. plot('datum')
#Calculating datum with respect to other factors

# %%
sns.histplot(data = df, x = 'Hour', hue = 'Month')
plt.show()
#month wise

# %%
sns.countplot(data = df, x = 'Hour', hue = 'Year')
plt.show()
# No of working Hours in a year

# %%
import pandas as pd
from google .colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5d4ea7dd-98a0-478f-a465-1a9e9d0bfbbd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5d4ea7dd-98a0-478f-a465-1a9e9d0bfbbd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sales hourly.csv to sales hourly.csv

# %%
ab = pd.read_csv('sales hourly.csv')
ab
# Out:
#                   datum  M01AB  M01AE  N02BA  ...  Year  Month  Hour  Weekday Name
# 0      01-02-2014 08:00   0.00   0.67    0.4  ...  2014      1     8      Thursday
# 1      01-02-2014 09:00   0.00   0.00    1.0  ...  2014      1     9      Thursday
# 2      01-02-2014 10:00   0.00   0.00    0.0  ...  2014      1    10      Thursday
# 3      01-02-2014 11:00   0.00   0.00    0.0  ...  2014      1    11      Thursday
# 4      01-02-2014 12:00   0.00   2.00    0.0  ...  2014      1    12      Thursday
# ...                 ...    ...    ...    ...  ...   ...    ...   ...           ...
# 50527  10-08-2019 15:00   0.00   0.40    0.0  ...  2019     10    15       Tuesday
# 50528  10-08-2019 16:00   0.33   0.00    0.0  ...  2019     10    16       Tuesday
# 50529  10-08-2019 17:00   0.00   0.00    0.0  ...  2019     10    17       Tuesday
# 50530  10-08-2019 18:00   0.00   0.00    0.0  ...  2019     10    18       Tuesday
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(ab)

# %%
sns.set_theme(color_codes = True)
sns.regplot(x = 'Hour', y = 'M01AB',  data = ab)
# No of sales done by M01AB with respect to hour

# %%
sns.catplot(x = 'Hour', y = 'M01AE', hue = 'Year', data = ab)
#No of M01AE sales done with respect to year and hour

# %%
sns.catplot(x = 'Hour', y = 'N02BA',hue = 'Year', data = ab)
#No of N02BA sales done with respect to year and hour

# %%
sns.catplot(x = 'Hour', y = 'N02BE',hue = 'Year', data = ab)
#No of N02BE sales done with respect to year and hour

# %%
sns.catplot(x = 'Hour', y = 'N05B',hue = 'Year', data = ab)
#No of N05B sales done with respect to year and hour

# %%
sns.catplot(x = 'Hour', y = 'N05C', hue = 'Year', data = ab)
#No of N05C sales done with respect to year and hour

# %%
sns.catplot(x = 'Hour', y = 'R03',hue = 'Year', data = ab)
#No of R03 sales done with respect to year and hour

# %%
sns.catplot(x = 'Hour', y = 'R06',hue = 'Year', data = ab)
#No of R06 sales done with respect to year and hour

# %%
import pandas as pd
from google.colab import files
uploaded() = files.upload
# Out:
#      <input type="file" id="files-2d543e7b-d54f-40d5-bc2f-14ada148f444" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2d543e7b-d54f-40d5-bc2f-14ada148f444">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving salesmonthly.csv to salesmonthly.csv

# %%
cd = pd.read_csv('salesmonthly.csv')
cd
# Out:
#          datum   M01AB    M01AE    N02BA     N02BE   N05B  N05C    R03     R06
# 0   2014-01-31  127.69   99.090  152.100   878.030  354.0  50.0  112.0   48.20
# 1   2014-02-28  133.32  126.050  177.000  1001.900  347.0  31.0  122.0   36.20
# 2   2014-03-31  137.44   92.950  147.655   779.275  232.0  20.0  112.0   85.40
# 3   2014-04-30  113.10   89.475  130.900   698.500  209.0  18.0   97.0   73.70
# 4   2014-05-31  101.79  119.933  132.100   628.780  270.0  23.0  107.0  123.70
# ..         ...     ...      ...      ...       ...    ...   ...    ...     ...
# 65  2019-06-30  151.54  101.627  103.200   610.000  193.0  25.0  142.0  156.04
# 66  2019-07-31  181.00  103.541   92.800   649.800  250.6  20.0  115.0  105.20
# 67  2019-08-31  181.91   88.269   84.200   518.100  237.0  26.0  145.0   97.30
# 68  2019-09-30  161.07  111.437   93.500   984.480  227.8  16.0  161.0  109.10
# 69  2019-10-31   44.37   37.300   20.650   295.150   86.0   7.0   37.0   11.13
#
# [70 rows x 9 columns]

# %%
import seaborn as sns
sns.histplot( data =cd, x = 'datum', y = 'M01AB')
# Sales done by M01AB with respect to date and the highest sales done is more than 200 and lowest of 20

# %%
sns.histplot( data =cd, x = 'datum', y = 'M01AE', color = 'pink')
# Sales done by M01AE with respect to date and the highest sales done is more than 200 and lowest of 10

# %%
sns.histplot(data = cd, x = 'datum', y = 'N02BA')
# Sales done by N02BA with respect to date and the highest sales done is more than 180 and lowest of 15

# %%
sns.histplot( data =cd, x = 'datum', y = 'N02BE')
# Sales done by N02BE with respect to date and the highest sales done is more than 1750 and lowest of 20

# %%
sns.histplot( data =cd, x = 'datum', y = 'N05B')
# Sales done by N05B with respect to date and the highest sales done is more than 480 and lowest of 20

# %%
sns.histplot( data =cd, x = 'datum', y = 'N05C')
# Sales done by N05C with respect to date and the highest sales done is more than 50 and lowest of 20

# %%
sns.histplot( data =cd, x = 'datum', y = 'R03', color = 'black')
# Sales done by R03 with respect to date and the highest sales done is more than 380 and lowest of 20

# %%
sns.histplot( data =cd, x = 'datum', y = 'R06', color = 'Green')
# Sales done by R06 with respect to date and the highest sales done is more than 200 and lowest of 10
