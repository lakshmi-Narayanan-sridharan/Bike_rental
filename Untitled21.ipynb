# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmi-Narayanan-sridharan/Bike_rental/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e4820226-abb7-4cb0-b67a-00816b77a710" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e4820226-abb7-4cb0-b67a-00816b77a710">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mosquito.csv.zip to mosquito.csv.zip

# %%
df = pd.read_csv('mosquito.csv.zip')
df
# Out:
#              Date  ... WnvPresent
# 0      2007-05-29  ...          0
# 1      2007-05-29  ...          0
# 2      2007-05-29  ...          0
# 3      2007-05-29  ...          0
# 4      2007-05-29  ...          0
# ...           ...  ...        ...
# 10501  2013-09-26  ...          1
# 10502  2013-09-26  ...          0
# 10503  2013-09-26  ...          0
# 10504  2013-09-26  ...          0
# 10505  2013-09-26  ...          0
#
# [10506 rows x 12 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.scatterplot(data = df, x = "Date", y = "Trap", hue = "Block")
plt.show()
# Which place the trap has been set on a day

# %%
sns.histplot (data = df, x = "NumMosquitos")
plt.show()
#Count of Mosquitos

# %%
sns.countplot(data = df, x ="NumMosquitos", hue = "WnvPresent")
plt.show()

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
df = pd.read_csv("mosquito.csv.zip")
sns.histplot(data = df, x ="Date", hue = "Species")
#Species found on the basis of Date

# %%
sns.heatmap(df.corr())

# %%
sns.factorplot(x = "Address", y = "AddressAccuracy", data = df)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.lineplot(data = df, x = "Date", y ="NumMosquitos", hue = "WnvPresent")

# %%
sns.
