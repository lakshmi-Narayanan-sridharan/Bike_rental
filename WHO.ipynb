# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmi-Narayanan-sridharan/Bike_rental/blob/main/WHO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0428d645-36a5-4bed-8063-727c97b5e6ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0428d645-36a5-4bed-8063-727c97b5e6ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving WHO1.csv to WHO1.csv

# %%
df = pd.read_csv('WHO1.csv')
df
# Out:
#                 Country  ...  Urban_population_pct_of_total
# 0           Afghanistan  ...                           22.9
# 1               Albania  ...                           45.4
# 2               Algeria  ...                           63.3
# 3               Andorra  ...                            0.0
# 4                Angola  ...                           53.3
# ..                  ...  ...                            ...
# 197             Vietnam  ...                           26.4
# 198  West Bank and Gaza  ...                           71.6
# 199               Yemen  ...                           27.3
# 200              Zambia  ...                           35.0
# 201            Zimbabwe  ...                           35.9
#
# [202 rows x 358 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.stripplot(data = df, x = "CountryID", hue = 'Adult literacy rate (%)')
#Adult literacy rate according to the country Id

# %%
sns.displot(data = df, x = 'CountryID', y = 'Adult literacy rate (%)', hue = 'Continent')
#Adult literacy rate according to countries

# %%
sns.scatterplot(data = df, x = 'CountryID', y = 'Gross national income per capita (PPP international $)', hue = 'Continent')
#Gross National Income according to the countries

# %%
sns.lineplot(data = df, x = 'Population (in thousands) total', y = 'Population annual growth rate (%)')
# Total Number of people and their growth rate

# %%
sns.lineplot(data = df, x = 'CountryID', y = 'Population in urban areas (%)')
#Population in urban areas

# %%
sns.lineplot(data = df, x  = 'Population living below the poverty line (% living on &lt; US$1 per day)', y = 'Population (in thousands) total')
#People living below the powerty line compared to whole population

# %%
sns.countplot(data = df, x = 'Population living below the poverty line (% living on &lt; US$1 per day)')
#People earning less than $1 are mostly from Afganisthan and Albania

# %%
sns.lineplot(data = df, x = 'Population proportion over 60 (%)', y = 'Population proportion under 15 (%)')
#Difference between people above the age 60 and under the age 15 is calculated

# %%
sns.scatterplot(data = df, x = 'Registration coverage of births (%)', y = 'Population (in thousands) total', hue = 'CountryID')
#Congo, Dem. Rep. this country birth rate is high compared to other countries

# %%
sns.lineplot(data = df, x ='Adolescent fertility rate (%)', y = 'Total fertility rate (per woman)')
#Fertility rate of women

# %%
sns.lineplot(data = df, x = 'Antenatal care coverage - at least four visits (%)', y = 'Antiretroviral therapy coverage among HIV-infected pregt women for PMTCT (%)')
# Persons who has confirmed affected by HIV after the fourth visit is stated

# %%
sns.scatterplot(data = df, x = 'Antiretroviral therapy coverage among people with advanced HIV infections (%)', y = 'Antiretroviral therapy coverage among HIV-infected pregt women for PMTCT (%)')
#HIV affected normal people vs pregnant women

# %%
sns.displot(data = df, x = 'Births attended by skilled health personnel (%)', y = 'Births by caesarean section (%)')
#Normal delivery vs Caesarean

# %%
sns.scatterplot(data = df, x = 'Children aged 6-59 months who received vitamin A supplementation (%)', y = 'Children aged &lt;5 years sleeping under insecticide-treated nets (%)' )
# Comparision of children who are having Vitamin A supplementation vs children who are under treatment

# %%
sns.displot(data = df, x = 'Children aged &lt;5 years who received any antimalarial treatment for fever (%)', y = 'Births attended by skilled health personnel (%)', hue = 'Births by caesarean section (%)')
#Births given by skilled persons

# %%
sns.scatterplot(data = df, x = 'Children aged &lt;5 years with ARI symptoms taken to facility (%)', y = 'Births attended by skilled health personnel (%)', hue = 'Births by caesarean section (%)')
#ARI symptoms in children who are all skilled health personnel vs who are all caesarean

# %%
sns.displot(data = df, x = 'Children aged &lt;5 years with diarrhoea receiving ORT (%)', y = 'Births attended by skilled health personnel (%)', hue = 'Births by caesarean section (%)')
#children who are suffering from diarrhoea

# %%
sns.lineplot(data = df, x = 'One-year-olds immunized with three doses of diphtheria tetanus toxoid and pertussis (DTP3) (%)', y = 'One-year-olds immunized with three doses of Hepatitis B (HepB3) (%)')
#Children who are all immunized with three doses

# %%
sns.scatterplot(data = df, x = 'One-year-olds immunized with three doses of Hib (Hib3) vaccine (%)', y = 'Contraceptive prevalence (%)', color = 'black')
#Count of child with three doses of Hib

# %%
sns.lineplot(data = df, x = 'Tuberculosis detection rate under DOTS (%)', y = 'Tuberculosis treatment success under DOTS (%)')
#Tuberculosis detection

# %%
sns.swarmplot(data = df, x = 'Women who have had mammography (%)', y =	'Women who have had PAP smear (%)')
# women who had nammography vs women who had PAP smear
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 97.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 60.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.displot(data = df, x = 'Community and traditional health workers density (per 10 000 population)', y = 'Dentistry personnel density (per 10 000 population)', hue = 'Environment and public health workers density (per 10 000 population)')
#Public health workers count

# %%
sns.scatterplot(data = df, x = 'CountryID', y = 'Population_total')
#Total population recorded by the countries worldwide

# %%
sns.catplot(data = df, x = 'Primary_energy_consumption', y =	'Primary_energy_consumption_per_person')
#Primary energy conception vs per person

# %%
sns.displot(data = df, x = 'Primary_school_completion_pct_of_boys', y ='Primary_school_completion_pct_of_girls')
# Primary competition of boys vs girls

# %%
sns.scatterplot(data = df, x = 'Prostate_cancer_deaths_per_100_000_men',y ='Prostate_cancer_new_cases_per_100_000_men', hue ='Prostate_cancer_number_of_male_deaths'	)
#prostate cancer deaths and new cases among men

# %%
sns.catplot(data = df,x = 'Ratio_of_girls_to_boys_in_primary_and_secondary_education', y ='Ratio_of_young_literate_females_to_males')
#Boys and girls ratio of education

# %%
sns.lineplot(data = df,x ='Roads_paved', y = 'SO2_emissions_per_person', hue = 'Services_contribution_to_economy')
#SO2 emission per person

# %%
sns.catplot(data = df, x = 'Stomach_cancer_number_of_female_deaths', y = 'Stomach_cancer_number_of_male_deaths')
#No of female deaths vs male deaths

# %%
sns.scatterplot(data = df,x = 'Stomach_cancer_number_of_new_female_cases',y = 'Stomach_cancer_number_of_new_male_cases')
#Male vs female stomach cancer patients

# %%
sns.scatterplot(data = df, x = 'Urban_population',y = 'Urban_population_growth', hue ='Urban_population_pct_of_total')
#Urban population vs growth
